# %%
#@title Import relevant modules
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt

# The following lines adjust the granularity of reporting. 
pd.options.display.max_rows = 10
pd.options.display.float_format = "{:.1f}".format

# %%
# Import the dataset.
training_df = pd.read_csv(filepath_or_buffer="https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv")

# Scale the label.
training_df["median_house_value"] /= 1000.0

# Print the first rows of the pandas DataFrame.
training_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.3      34.2                15.0       5612.0          1283.0
# 1     -114.5      34.4                19.0       7650.0          1901.0
# 2     -114.6      33.7                17.0        720.0           174.0
# 3     -114.6      33.6                14.0       1501.0           337.0
# 4     -114.6      33.6                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0            1.5                66.9
# 1      1129.0       463.0            1.8                80.1
# 2       333.0       117.0            1.7                85.7
# 3       515.0       226.0            3.2                73.4
# 4       624.0       262.0            1.9                65.5

# %%
training_df.describe()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count    17000.0   17000.0             17000.0      17000.0         17000.0
# mean      -119.6      35.6                28.6       2643.7           539.4
# std          2.0       2.1                12.6       2179.9           421.5
# min       -124.3      32.5                 1.0          2.0             1.0
# 25%       -121.8      33.9                18.0       1462.0           297.0
# 50%       -118.5      34.2                29.0       2127.0           434.0
# 75%       -118.0      37.7                37.0       3151.2           648.2
# max       -114.3      42.0                52.0      37937.0          6445.0
#
#        population  households  median_income  median_house_value
# count     17000.0     17000.0        17000.0             17000.0
# mean       1429.6       501.2            3.9               207.3
# std        1147.9       384.5            1.9               116.0
# min           3.0         1.0            0.5                15.0
# 25%         790.0       282.0            2.6               119.4
# 50%        1167.0       409.0            3.5               180.4
# 75%        1721.0       605.2            4.8               265.0
# max       35682.0      6082.0           15.0               500.0

# %%
#@title Define the functions that build and train a model
def build_model(my_learning_rate):
  """Create and compile a simple linear regression model."""
  # Most simple tf.keras models are sequential.
  model = tf.keras.models.Sequential()

  # Describe the topography of the model.
  # The topography of a simple linear regression model
  # is a single node in a single layer.
  model.add(tf.keras.layers.Dense(units=1, 
                                  input_shape=(1,)))

  # Compile the model topography into code that TensorFlow can efficiently
  # execute. Configure training to minimize the model's mean squared error. 
  model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.RootMeanSquaredError()])

  return model        


def train_model(model, df, feature, label, epochs, batch_size):
  """Train the model by feeding it data."""

  # Feed the model the feature and the label.
  # The model will train for the specified number of epochs. 
  history = model.fit(x=df[feature],
                      y=df[label],
                      batch_size=batch_size,
                      epochs=epochs)

  # Gather the trained model's weight and bias.
  trained_weight = model.get_weights()[0]
  trained_bias = model.get_weights()[1]

  # The list of epochs is stored separately from the rest of history.
  epochs = history.epoch
  
  # Isolate the error for each epoch.
  hist = pd.DataFrame(history.history)

  # To track the progression of training, we're going to take a snapshot
  # of the model's root mean squared error at each epoch. 
  rmse = hist["root_mean_squared_error"]

  return trained_weight, trained_bias, epochs, rmse

print("Defined the build_model and train_model functions.")
# Out:
# Defined the build_model and train_model functions.

# %%
#@title Define the plotting functions
def plot_the_model(trained_weight, trained_bias, feature, label):
  """Plot the trained model against 200 random training examples."""

  # Label the axes.
  plt.xlabel(feature)
  plt.ylabel(label)

  # Create a scatter plot from 200 random points of the dataset.
  random_examples = training_df.sample(n=200)
  plt.scatter(random_examples[feature], random_examples[label])

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = random_examples[feature].max()
  y1 = trained_bias + (trained_weight * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()


def plot_the_loss_curve(epochs, rmse):
  """Plot a curve of loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")

  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([rmse.min()*0.97, rmse.max()])
  plt.show()  

print("Defined the plot_the_model and plot_the_loss_curve functions.")
# Out:
# Defined the plot_the_model and plot_the_loss_curve functions.

# %%
# The following variables are the hyperparameters.
learning_rate = 0.005
epochs = 30
batch_size = 10

# Specify the feature and the label.
my_feature = "population"  # the total number of rooms on a specific city block.
my_label="median_house_value" # the median value of a house on a specific city block.
# That is, you're going to create a model that predicts house value based 
# solely on total_rooms.  

# Discard any pre-existing version of the model.
my_model = None

# Invoke the functions.
my_model = build_model(learning_rate)
weight, bias, epochs, rmse = train_model(my_model, training_df, 
                                         my_feature, my_label,
                                         epochs, batch_size)

print("\nThe learned weight for your model is %.4f" % weight)
print("The learned bias for your model is %.4f\n" % bias )

plot_the_model(weight, bias, my_feature, my_label)
plot_the_loss_curve(epochs, rmse)
# Out:
# Epoch 1/30
# 1700/1700 [==============================] - 3s 1ms/step - loss: 507276.8438 - root_mean_squared_error: 712.2337
# Epoch 2/30
# 1700/1700 [==============================] - 3s 1ms/step - loss: 29730.1074 - root_mean_squared_error: 172.4242
# Epoch 3/30
# 1700/1700 [==============================] - 3s 1ms/step - loss: 28516.1328 - root_mean_squared_error: 168.8672
# Epoch 4/30
# 1700/1700 [==============================] - 3s 2ms/step - loss: 27549.2832 - root_mean_squared_error: 165.9798
# Epoch 5/30
# 1700/1700 [==============================] - 3s 1ms/step - loss: 26772.7988 - root_mean_squared_error: 163.6239
# Epoch 6/30
# 1700/1700 [==============================] - 3s 2ms/step - loss: 25714.3926 - root_mean_squared_error: 160.3571
# Epoch 7/30
# 1700/1700 [==============================] - 3s 2ms/step - loss: 25087.9512 - root_mean_squared_error: 158.3918
# Epoch 8/30
# 1700/1700 [==============================] - 3s 1ms/step - loss: 24129.9961 - root_mean_squared_error: 155.3383
# Epoch 9/30
# 1700/1700 [==============================] - 3s 1ms/step - loss: 23130.9902 - root_mean_squared_error: 152.0888
# Epoch 10/30
# 1700/1700 [==============================] - 3s 1ms/step - loss: 22384.4082 - root_mean_squared_error: 149.6142
# Epoch 11/30
# 1700/1700 [==============================] - 3s 2ms/step - loss: 21589.4004 - root_mean_squared_error: 146.9333
# Epoch 12/30
# 1700/1700 [==============================] - 3s 2ms/step - loss: 20984.7285 - root_mean_squared_error: 144.8611
# Epoch 13/30
# 1700/1700 [==============================] - 3s 2ms/step - loss: 20372.5703 - root_mean_squared_error: 142.7325
# Epoch 14/30
# 1700/1700 [==============================] - 3s 2ms/step - loss: 19719.5605 - root_mean_squared_error: 140.4263
# Epoch 15/30
# 1700/1700 [==============================] - 3s 2ms/step - loss: 19183.9102 - root_mean_squared_error: 138.5060
# Epoch 16/30
# 1700/1700 [==============================] - 3s 1ms/step - loss: 18666.2031 - root_mean_squared_error: 136.6243
# Epoch 17/30
# 1700/1700 [==============================] - 3s 2ms/step - loss: 18109.6641 - root_mean_squared_error: 134.5722
# Epoch 18/30
# 1700/1700 [==============================] - 3s 2ms/step - loss: 17821.7383 - root_mean_squared_error: 133.4981
# Epoch 19/30
# 1700/1700 [==============================] - 3s 2ms/step - loss: 17271.1387 - root_mean_squared_error: 131.4197
# Epoch 20/30
# 1700/1700 [==============================] - 3s 2ms/step - loss: 16851.9355 - root_mean_squared_error: 129.8150
# Epoch 21/30
# 1700/1700 [==============================] - 3s 2ms/step - loss: 16444.3027 - root_mean_squared_error: 128.2353
# Epoch 22/30
# 1700/1700 [==============================] - 3s 2ms/step - loss: 16154.2002 - root_mean_squared_error: 127.0992
# Epoch 23/30
# 1700/1700 [==============================] - 3s 2ms/step - loss: 15877.3213 - root_mean_squared_error: 126.0052
# Epoch 24/30
# 1700/1700 [==============================] - 3s 2ms/step - loss: 15684.1943 - root_mean_squared_error: 125.2365
# Epoch 25/30
# 1700/1700 [==============================] - 3s 1ms/step - loss: 15468.7988 - root_mean_squared_error: 124.3736
# Epoch 26/30
# 1700/1700 [==============================] - 3s 2ms/step - loss: 15134.7236 - root_mean_squared_error: 123.0233
# Epoch 27/30
# 1700/1700 [==============================] - 3s 1ms/step - loss: 14964.2490 - root_mean_squared_error: 122.3284
# Epoch 28/30
# 1700/1700 [==============================] - 3s 1ms/step - loss: 14778.4932 - root_mean_squared_error: 121.5668
# Epoch 29/30
# 1700/1700 [==============================] - 3s 1ms/step - loss: 14643.7021 - root_mean_squared_error: 121.0112
# Epoch 30/30
# 1700/1700 [==============================] - 3s 1ms/step - loss: 14473.6279 - root_mean_squared_error: 120.3064
#
# The learned weight for your model is 0.0251
# The learned bias for your model is 165.4455
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
def predict_house_values(n, feature, label):
  """Predict house values based on a feature."""

  batch = training_df[feature][10000:10000 + n]
  predicted_values = my_model.predict_on_batch(x=batch)

  print("feature   label          predicted")
  print("  value   value          value")
  print("          in thousand$   in thousand$")
  print("--------------------------------------")
  for i in range(n):
    print ("%5.0f %6.0f %15.0f" % (training_df[feature][10000 + i],
                                   training_df[label][10000 + i],
                                   predicted_values[i][0] ))

# %%
predict_house_values(10, my_feature, my_label)
# Out:
# feature   label          predicted
#   value   value          value
#           in thousand$   in thousand$
# --------------------------------------
#  1286     53             198
#  1867     92             212
#  2191     69             220
#  1052     62             192
#  1647     80             207
#  2312    295             223
#  1604    500             206
#  1066    342             192
#   338    118             174
#  1604    128             206

# %%
my_feature = "population"   # Replace the ? with population or possibly
                   # a different column name.

# Experiment with the hyperparameters.
learning_rate = 0.05
epochs = 18
batch_size = 3

# Don't change anything below this line.
my_model = build_model(learning_rate)
weight, bias, epochs, rmse = train_model(my_model, training_df, 
                                         my_feature, my_label,
                                         epochs, batch_size)
plot_the_model(weight, bias, my_feature, my_label)
plot_the_loss_curve(epochs, rmse)

predict_house_values(15, my_feature, my_label)
# Out:
# Epoch 1/18
# 5667/5667 [==============================] - 12s 2ms/step - loss: 30625.0020 - root_mean_squared_error: 175.0000
# Epoch 2/18
# 5667/5667 [==============================] - 12s 2ms/step - loss: 19783.3262 - root_mean_squared_error: 140.6532
# Epoch 3/18
# 5667/5667 [==============================] - 12s 2ms/step - loss: 18422.1465 - root_mean_squared_error: 135.7282
# Epoch 4/18
# 5667/5667 [==============================] - 14s 2ms/step - loss: 17816.2539 - root_mean_squared_error: 133.4775
# Epoch 5/18
# 5667/5667 [==============================] - 14s 2ms/step - loss: 18186.6230 - root_mean_squared_error: 134.8578
# Epoch 6/18
# 5667/5667 [==============================] - 14s 2ms/step - loss: 18010.2812 - root_mean_squared_error: 134.2024
# Epoch 7/18
# 5667/5667 [==============================] - 14s 2ms/step - loss: 18365.0996 - root_mean_squared_error: 135.5179
# Epoch 8/18
# 5667/5667 [==============================] - 14s 2ms/step - loss: 18020.0820 - root_mean_squared_error: 134.2389
# Epoch 9/18
# 5667/5667 [==============================] - 14s 2ms/step - loss: 18103.4395 - root_mean_squared_error: 134.5490
# Epoch 10/18
# 5667/5667 [==============================] - 14s 2ms/step - loss: 17960.3047 - root_mean_squared_error: 134.0161
# Epoch 11/18
# 5667/5667 [==============================] - 14s 2ms/step - loss: 18030.8105 - root_mean_squared_error: 134.2789
# Epoch 12/18
# 5667/5667 [==============================] - 14s 2ms/step - loss: 18025.0156 - root_mean_squared_error: 134.2573
# Epoch 13/18
# 5667/5667 [==============================] - 14s 2ms/step - loss: 17684.4375 - root_mean_squared_error: 132.9828
# Epoch 14/18
# 5667/5667 [==============================] - 14s 2ms/step - loss: 18141.4414 - root_mean_squared_error: 134.6902
# Epoch 15/18
# 5667/5667 [==============================] - 14s 2ms/step - loss: 18579.7285 - root_mean_squared_error: 136.3075
# Epoch 16/18
# 5667/5667 [==============================] - 14s 2ms/step - loss: 17945.1504 - root_mean_squared_error: 133.9595
# Epoch 17/18
# 5667/5667 [==============================] - 14s 2ms/step - loss: 17967.6992 - root_mean_squared_error: 134.0436
# Epoch 18/18
# 5667/5667 [==============================] - 14s 2ms/step - loss: 17961.9238 - root_mean_squared_error: 134.0221
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# feature   label          predicted
#   value   value          value
#           in thousand$   in thousand$
# --------------------------------------
#  1286     53             209
#  1867     92             209
#  2191     69             208
#  1052     62             209
#  1647     80             209
#  2312    295             208
#  1604    500             209
#  1066    342             209
#   338    118             209
#  1604    128             209
#  1200    187             209
#   292     80             209
#  2014    112             209
#  1817     95             209
#  1328     69             209

# %%
#@title Double-click to view a possible solution to Task 4.

# Define a synthetic feature
training_df["rooms_per_person"] = training_df["total_rooms"] / training_df["population"]
my_feature = "rooms_per_person"

# Tune the hyperparameters.
learning_rate = 0.06
epochs = 24
batch_size = 30

# Don't change anything below this line.
my_model = build_model(learning_rate)
weight, bias, epochs, mae = train_model(my_model, training_df,
                                        my_feature, my_label,
                                        epochs, batch_size)

plot_the_loss_curve(epochs, mae)
predict_house_values(15, my_feature, my_label)
# Out:
# Epoch 1/24
# 567/567 [==============================] - 2s 2ms/step - loss: 37993.7383 - root_mean_squared_error: 194.9198
# Epoch 2/24
# 567/567 [==============================] - 1s 2ms/step - loss: 18995.0684 - root_mean_squared_error: 137.8226
# Epoch 3/24
# 567/567 [==============================] - 1s 2ms/step - loss: 15153.8789 - root_mean_squared_error: 123.1011
# Epoch 4/24
# 567/567 [==============================] - 1s 2ms/step - loss: 14959.6025 - root_mean_squared_error: 122.3094
# Epoch 5/24
# 567/567 [==============================] - 1s 2ms/step - loss: 14761.3242 - root_mean_squared_error: 121.4962
# Epoch 6/24
# 567/567 [==============================] - 1s 2ms/step - loss: 14567.4834 - root_mean_squared_error: 120.6958
# Epoch 7/24
# 567/567 [==============================] - 1s 2ms/step - loss: 14400.8809 - root_mean_squared_error: 120.0037
# Epoch 8/24
# 567/567 [==============================] - 1s 3ms/step - loss: 14234.2676 - root_mean_squared_error: 119.3074
# Epoch 9/24
# 567/567 [==============================] - 1s 2ms/step - loss: 14131.8975 - root_mean_squared_error: 118.8777
# Epoch 10/24
# 567/567 [==============================] - 1s 2ms/step - loss: 14060.4736 - root_mean_squared_error: 118.5769
# Epoch 11/24
# 567/567 [==============================] - 1s 2ms/step - loss: 13921.6055 - root_mean_squared_error: 117.9899
# Epoch 12/24
# 567/567 [==============================] - 1s 2ms/step - loss: 13847.7852 - root_mean_squared_error: 117.6766
# Epoch 13/24
# 567/567 [==============================] - 1s 3ms/step - loss: 13760.2109 - root_mean_squared_error: 117.3039
# Epoch 14/24
# 567/567 [==============================] - 1s 2ms/step - loss: 13704.2354 - root_mean_squared_error: 117.0651
# Epoch 15/24
# 567/567 [==============================] - 1s 2ms/step - loss: 13629.8320 - root_mean_squared_error: 116.7469
# Epoch 16/24
# 567/567 [==============================] - 1s 3ms/step - loss: 13580.0645 - root_mean_squared_error: 116.5335
# Epoch 17/24
# 567/567 [==============================] - 1s 2ms/step - loss: 13548.6729 - root_mean_squared_error: 116.3988
# Epoch 18/24
# 567/567 [==============================] - 1s 2ms/step - loss: 13497.0811 - root_mean_squared_error: 116.1769
# Epoch 19/24
# 567/567 [==============================] - 1s 2ms/step - loss: 13480.5312 - root_mean_squared_error: 116.1057
# Epoch 20/24
# 567/567 [==============================] - 1s 3ms/step - loss: 13445.2471 - root_mean_squared_error: 115.9536
# Epoch 21/24
# 567/567 [==============================] - 1s 2ms/step - loss: 13432.5439 - root_mean_squared_error: 115.8988
# Epoch 22/24
# 567/567 [==============================] - 1s 2ms/step - loss: 13427.2783 - root_mean_squared_error: 115.8761
# Epoch 23/24
# 567/567 [==============================] - 1s 2ms/step - loss: 13384.5498 - root_mean_squared_error: 115.6916
# Epoch 24/24
# 567/567 [==============================] - 1s 2ms/step - loss: 13384.6416 - root_mean_squared_error: 115.6920
# feature   label          predicted
#   value   value          value
#           in thousand$   in thousand$
# --------------------------------------
#     2     53             187
#     2     92             198
#     2     69             193
#     2     62             209
#     1     80             184
#     2    295             223
#     2    500             208
#     2    342             221
#     4    118             284
#     2    128             212
#     2    187             221
#     3     80             232
#     2    112             222
#     2     95             217
#     2     69             208

# %%
# Generate a correlation matrix.
training_df.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude                 1.0      -0.9                -0.1          0.0
# latitude                 -0.9       1.0                 0.0         -0.0
# housing_median_age       -0.1       0.0                 1.0         -0.4
# total_rooms               0.0      -0.0                -0.4          1.0
# total_bedrooms            0.1      -0.1                -0.3          0.9
# population                0.1      -0.1                -0.3          0.9
# households                0.1      -0.1                -0.3          0.9
# median_income            -0.0      -0.1                -0.1          0.2
# median_house_value       -0.0      -0.1                 0.1          0.1
# rooms_per_person         -0.1       0.1                -0.1          0.1
#
#                     total_bedrooms  population  households  median_income  \
# longitude                      0.1         0.1         0.1           -0.0
# latitude                      -0.1        -0.1        -0.1           -0.1
# housing_median_age            -0.3        -0.3        -0.3           -0.1
# total_rooms                    0.9         0.9         0.9            0.2
# total_bedrooms                 1.0         0.9         1.0           -0.0
# population                     0.9         1.0         0.9           -0.0
# households                     1.0         0.9         1.0            0.0
# median_income                 -0.0        -0.0         0.0            1.0
# median_house_value             0.0        -0.0         0.1            0.7
# rooms_per_person               0.0        -0.1        -0.0            0.2
#
#                     median_house_value  rooms_per_person
# longitude                         -0.0              -0.1
# latitude                          -0.1               0.1
# housing_median_age                 0.1              -0.1
# total_rooms                        0.1               0.1
# total_bedrooms                     0.0               0.0
# population                        -0.0              -0.1
# households                         0.1              -0.0
# median_income                      0.7               0.2
# median_house_value                 1.0               0.2
# rooms_per_person                   0.2               1.0

# %%
my_feature = "median_income"   # Replace the ? with population or possibly
                   # a different column name.

# Experiment with the hyperparameters.
learning_rate = 0.005
epochs = 30
batch_size = 30

# Don't change anything below this line.
my_model = build_model(learning_rate)
weight, bias, epochs, rmse = train_model(my_model, training_df, 
                                         my_feature, my_label,
                                         epochs, batch_size)
plot_the_model(weight, bias, my_feature, my_label)
plot_the_loss_curve(epochs, rmse)

predict_house_values(15, my_feature, my_label)
# Out:
# Epoch 1/30
# 567/567 [==============================] - 2s 2ms/step - loss: 56100.4805 - root_mean_squared_error: 236.8554
# Epoch 2/30
# 567/567 [==============================] - 1s 2ms/step - loss: 49862.8047 - root_mean_squared_error: 223.2998
# Epoch 3/30
# 567/567 [==============================] - 1s 2ms/step - loss: 44013.6172 - root_mean_squared_error: 209.7942
# Epoch 4/30
# 567/567 [==============================] - 1s 2ms/step - loss: 38618.0273 - root_mean_squared_error: 196.5147
# Epoch 5/30
# 567/567 [==============================] - 1s 2ms/step - loss: 33663.3672 - root_mean_squared_error: 183.4758
# Epoch 6/30
# 567/567 [==============================] - 1s 2ms/step - loss: 29101.0137 - root_mean_squared_error: 170.5902
# Epoch 7/30
# 567/567 [==============================] - 1s 2ms/step - loss: 25006.4355 - root_mean_squared_error: 158.1342
# Epoch 8/30
# 567/567 [==============================] - 1s 2ms/step - loss: 21308.8457 - root_mean_squared_error: 145.9755
# Epoch 9/30
# 567/567 [==============================] - 1s 2ms/step - loss: 18073.0625 - root_mean_squared_error: 134.4361
# Epoch 10/30
# 567/567 [==============================] - 1s 2ms/step - loss: 15243.3027 - root_mean_squared_error: 123.4638
# Epoch 11/30
# 567/567 [==============================] - 1s 2ms/step - loss: 12838.9004 - root_mean_squared_error: 113.3089
# Epoch 12/30
# 567/567 [==============================] - 1s 2ms/step - loss: 10858.3232 - root_mean_squared_error: 104.2033
# Epoch 13/30
# 567/567 [==============================] - 1s 2ms/step - loss: 9322.9863 - root_mean_squared_error: 96.5556
# Epoch 14/30
# 567/567 [==============================] - 1s 2ms/step - loss: 8213.3809 - root_mean_squared_error: 90.6277
# Epoch 15/30
# 567/567 [==============================] - 1s 2ms/step - loss: 7507.7227 - root_mean_squared_error: 86.6471
# Epoch 16/30
# 567/567 [==============================] - 1s 2ms/step - loss: 7156.7681 - root_mean_squared_error: 84.5977
# Epoch 17/30
# 567/567 [==============================] - 1s 2ms/step - loss: 7044.8765 - root_mean_squared_error: 83.9338
# Epoch 18/30
# 567/567 [==============================] - 1s 2ms/step - loss: 7019.1260 - root_mean_squared_error: 83.7802
# Epoch 19/30
# 567/567 [==============================] - 1s 2ms/step - loss: 7014.0151 - root_mean_squared_error: 83.7497
# Epoch 20/30
# 567/567 [==============================] - 1s 2ms/step - loss: 7013.0312 - root_mean_squared_error: 83.7438
# Epoch 21/30
# 567/567 [==============================] - 1s 2ms/step - loss: 7012.6763 - root_mean_squared_error: 83.7417
# Epoch 22/30
# 567/567 [==============================] - 1s 2ms/step - loss: 7012.7617 - root_mean_squared_error: 83.7422
# Epoch 23/30
# 567/567 [==============================] - 1s 2ms/step - loss: 7012.7202 - root_mean_squared_error: 83.7420
# Epoch 24/30
# 567/567 [==============================] - 1s 2ms/step - loss: 7012.8125 - root_mean_squared_error: 83.7425
# Epoch 25/30
# 567/567 [==============================] - 1s 2ms/step - loss: 7012.8140 - root_mean_squared_error: 83.7425
# Epoch 26/30
# 567/567 [==============================] - 1s 2ms/step - loss: 7012.8599 - root_mean_squared_error: 83.7428
# Epoch 27/30
# 567/567 [==============================] - 1s 2ms/step - loss: 7012.8945 - root_mean_squared_error: 83.7430
# Epoch 28/30
# 567/567 [==============================] - 1s 2ms/step - loss: 7012.8564 - root_mean_squared_error: 83.7428
# Epoch 29/30
# 567/567 [==============================] - 1s 2ms/step - loss: 7012.7900 - root_mean_squared_error: 83.7424
# Epoch 30/30
# 567/567 [==============================] - 1s 2ms/step - loss: 7012.8379 - root_mean_squared_error: 83.7427
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# feature   label          predicted
#   value   value          value
#           in thousand$   in thousand$
# --------------------------------------
#     2     53             134
#     4     92             212
#     3     69             154
#     2     62             132
#     3     80             153
#     2    295             148
#    10    500             456
#     5    342             260
#     2    118             147
#     4    128             221
#     8    187             396
#     3     80             163
#     3    112             179
#     4     95             221
#     2     69             143
